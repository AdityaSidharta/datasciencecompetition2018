# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def plot_heatmap(csv_path):
    data = pd.read_csv(csv_path)
    average = np.sum(np.arange(34) * data.values[:,2:], axis=1) /2016
    data['ave'] = average
    sns.set()
    viz = radar
radar1 = pd.read_csv("./datasets/radar/2017-13.csv")
ave_0 = np.sum(np.arange(34) * radar1.values[:,2:], axis=1) /2016
radar1['ave_0'] = ave_0
radar1.rename(columns={'lat':'x', 'long':'y'}, inplace=True)
sns.set()
viz = radar1.pivot("x", 'y', 'ave_0')
f, ax = plt.subplots(figsize=(10, 10))
sns.heatmap(viz, square=True)
