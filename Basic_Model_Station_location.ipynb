# %%
filepath = '/home/adityasidharta/git/datascience2018/datasets'
gauge_path = filepath+'/gauge.csv'
radar_path = filepath+'/radar'

# %%
from tqdm import tqdm_notebook as tqdm
from scipy.stats import pearsonr

# %%
import pandas as pd
import numpy as np
import os

# %%
df_gauge = pd.read_csv(gauge_path)

# %%
df_result = pd.DataFrame()
train_week = []
for filename in tqdm(os.listdir(radar_path)):
    week = filename.split('.')[0][-2:]
    train_week.append(str(week))
    full_radar_path = os.path.join(radar_path, filename)
    df_radar = pd.read_csv(full_radar_path)
    radar_obs = df_radar.values[:,2:]
    radar_arange = np.arange(0, 34)
    radar_mean = np.matmul(radar_obs, radar_arange) / 2016.
    if 'latlong' not in df_result.columns:
        df_result['latlong'] = df_radar['lat'] * 1000 + df_radar['long']
    assert np.allclose(df_result['latlong'].values, df_radar['lat'] * 1000 + df_radar['long'])
    df_result['mean_week_'+str(week)] = radar_mean

# %%
train_week
# Out:
# ['47',
#  '45',
#  '35',
#  '20',
#  '18',
#  '21',
#  '31',
#  '22',
#  '29',
#  '51',
#  '38',
#  '39',
#  '26',
#  '50',
#  '33',
#  '37',
#  '19',
#  '48',
#  '16',
#  '28',
#  '36',
#  '17',
#  '46',
#  '44',
#  '13',
#  '32',
#  '49',
#  '15',
#  '23',
#  '24',
#  '41']

# %%
df_result = df_result[sorted(df_result.columns)]

# %%
df_result.head()
# Out:
#    latlong  mean_week_13  mean_week_15  mean_week_16  mean_week_17  \
# 0        0      0.675099      0.382937      0.535714      0.815476
# 1        1      0.714782      0.382440      0.493552      0.841270
# 2        2      0.742063      0.411706      0.519345      0.859127
# 3        3      0.746032      0.380456      0.522321      0.887897
# 4        4      0.745536      0.380456      0.519345      0.860119
#
#    mean_week_18  mean_week_19  mean_week_20  mean_week_21  mean_week_22  \
# 0      0.248016      0.237599      0.416667      0.908730      0.306052
# 1      0.258433      0.266369      0.450397      0.963790      0.289187
# 2      0.235615      0.260417      0.466270      0.968254      0.324901
# 3      0.247520      0.278274      0.474702      0.954365      0.307540
# 4      0.248016      0.277778      0.472222      0.950893      0.304563
#
#        ...       mean_week_39  mean_week_41  mean_week_44  mean_week_45  \
# 0      ...           0.193948      0.994544      0.695933      1.006944
# 1      ...           0.164683      0.980655      0.738591      1.010417
# 2      ...           0.145833      0.958333      0.691468      1.002480
# 3      ...           0.157738      0.932044      0.755952      1.075893
# 4      ...           0.155258      0.923115      0.771825      1.070933
#
#    mean_week_46  mean_week_47  mean_week_48  mean_week_49  mean_week_50  \
# 0      1.025298      0.670139      0.461310      0.645337      0.406250
# 1      1.021825      0.635913      0.457341      0.637897      0.339782
# 2      1.012897      0.616071      0.469742      0.611607      0.336806
# 3      1.037202      0.561012      0.494048      0.574405      0.350694
# 4      1.038690      0.553075      0.499008      0.573909      0.352183
#
#    mean_week_51
# 0      0.157242
# 1      0.183532
# 2      0.154266
# 3      0.157242
# 4      0.154266
#
# [5 rows x 32 columns]

# %%
df_gauge = pd.read_csv(gauge_path)

# %%
len(np.where(pd.isnull(df_gauge))[0])
# Out:
# 357

# %%
df_gauge['18']
# Out:
# 0      18.4
# 1       0.0
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15    109.2
# 16    119.6
# 17     69.8
# 18    107.0
# 19     16.0
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24     38.0
# 25      NaN
# 26      NaN
# 27    107.8
# 28      0.0
# 29     13.2
# 30     23.6
# 31     26.0
# 32     85.2
# 33     25.0
# 34      9.0
# 35      9.6
# 36     87.4
# 37     58.8
# 38     31.2
# 39     15.8
# 40     21.4
# 41      1.0
# 42     28.6
# 43     53.6
# 44     98.2
# 45     66.4
# 46    105.8
# 47      NaN
# 48      2.6
# 49     68.8
# 50     36.8
# 51      NaN
# Name: 18, dtype: float64

# %%
df_gauge['Year'] = df_gauge['Year'].astype(str)
df_gauge['Week'] = df_gauge['Week'].astype(str)
df_gauge = df_gauge.apply(lambda x: x.fillna(x[2:].mean()),axis=1)

# %%
train_week = sorted(train_week)

# %%
train_bool = df_gauge['Week'].apply(lambda x : x in train_week)
train_df_gauge = df_gauge[train_bool]

# %%
train_df_gauge_array = train_df_gauge.values[:, 2:]

# %%
train_df_gauge.head()
# Out:
#     Year Week      0      1     2     3      4     5     6      7    ...      \
# 12  2017   13   36.8   30.0  48.2  78.6   67.4  45.6  77.6   21.6    ...
# 14  2017   15   43.8   90.4  82.6  13.2   45.8  86.6  34.6   38.4    ...
# 15  2017   16   98.8  134.0  68.2  74.8   77.7  86.4  37.8  102.6    ...
# 16  2017   17  100.2   56.0  82.8  69.2  127.3  84.6  78.0   24.8    ...
# 17  2017   18    2.0   76.0   1.6   1.2   54.5  25.2  30.4   49.8    ...
#
#            40     41         42    43    44     45     46         47  \
# 12  37.800000   34.0  43.645455  19.4  25.2   26.6    4.8  57.000000
# 14  46.000000   99.0  66.773810  66.6  72.9   76.2   82.4  53.600000
# 15  97.579487  139.0  97.579487  58.6  69.7   68.2  162.6  97.579487
# 16  64.136842   46.2  89.200000  28.0  38.7  112.6   17.8  34.600000
# 17  36.884211   24.8  36.884211  29.2  25.5  109.8   71.6  14.000000
#
#             48         49
# 12  107.000000  54.000000
# 14   21.800000  66.773810
# 15   43.000000  97.579487
# 16   64.136842  32.400000
# 17   36.884211   9.600000
#
# [5 rows x 52 columns]

# %%
train_df_gauge_array.shape
# Out:
# (31, 50)

# %%
df_result['latlong'].values

# %%
print np.where(pd.isnull(train_df_gauge_array))
print np.where(pd.isnull(df_result))

# %%
df_corr_result = pd.DataFrame()
df_corr_result['latlong'] = df_result['latlong'].values
for station in tqdm(range(train_df_gauge_array.shape[1])):
    station_values = train_df_gauge_array[:, station]
    total_latlong = []
    for idx, latlong in tqdm(df_result.iterrows()):
        latlong_values = latlong.values[1:]
        correlation = np.corrcoef(station_values.tolist(), latlong_values.tolist())[0][1]
        total_latlong.append(correlation)
    df_corr_result['corr_station_'+str(station)] = total_latlong

# %%
df_corr_result.to_csv('adit_csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-fc109bc9100b> in <module>()
# ----> 1 df_corr_result.to_csv('adit_csv')
#
# NameError: name 'df_corr_result' is not defined

# %%
df_corr_result = pd.read_csv('adit.csv')
del df_corr_result['Unnamed: 0']

# %%
df_corr_result.sort('corr_station_0',ascending = False)
# Out:
# /home/adityasidharta/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   """Entry point for launching an IPython kernel.
#         latlong  corr_station_0  corr_station_1  corr_station_2  \
# 115904   241224        0.897161        0.310128        0.813285
# 115905   241225        0.889518        0.291900        0.801164
# 113987   237227        0.872859        0.199349        0.766339
# 116862   243222        0.872584        0.281486        0.791896
# 113504   236224        0.867482        0.264679        0.748601
# 113976   237216        0.866944        0.300562        0.765035
# 121661   253221        0.866850        0.273936        0.833843
# 114463   238223        0.866143        0.289142        0.753054
# 117336   244216        0.865474        0.298773        0.794120
# 113977   237217        0.864939        0.296706        0.764383
# 114936   239216        0.864002        0.308642        0.769230
# 112061   233221        0.862607        0.279021        0.746660
# 116866   243226        0.862089        0.254306        0.759963
# 115414   240214        0.859413        0.313203        0.763906
# 114457   238217        0.859280        0.305590        0.760792
# 115425   240225        0.859210        0.331908        0.783387
# 116865   243225        0.857982        0.266411        0.763867
# 115896   241216        0.857392        0.311107        0.773714
# 113978   237218        0.856643        0.314358        0.751494
# 114462   238222        0.856272        0.271529        0.759087
# 113974   237214        0.855948        0.273963        0.745840
# 113979   237219        0.855481        0.279386        0.740893
# 116376   242216        0.854890        0.320525        0.785781
# 112062   233222        0.854214        0.223873        0.726138
# 115421   240221        0.853565        0.275532        0.762656
# 111578   232218        0.852050        0.273389        0.725886
# 117814   245214        0.851530        0.323519        0.786680
# 114461   238221        0.851435        0.287617        0.746838
# 115417   240217        0.851423        0.301881        0.759339
# 115897   241217        0.851183        0.289036        0.759714
# ...         ...             ...             ...             ...
# 222848   464128             NaN             NaN             NaN
# 223192   464472             NaN             NaN             NaN
# 223273   465073             NaN             NaN             NaN
# 223274   465074             NaN             NaN             NaN
# 223275   465075             NaN             NaN             NaN
# 223672   465472             NaN             NaN             NaN
# 223677   465477             NaN             NaN             NaN
# 223678   465478             NaN             NaN             NaN
# 223686   466006             NaN             NaN             NaN
# 223867   466187             NaN             NaN             NaN
# 224152   466472             NaN             NaN             NaN
# 224155   466475             NaN             NaN             NaN
# 224156   466476             NaN             NaN             NaN
# 224166   467006             NaN             NaN             NaN
# 224534   467374             NaN             NaN             NaN
# 224633   467473             NaN             NaN             NaN
# 224646   468006             NaN             NaN             NaN
# 225126   469006             NaN             NaN             NaN
# 225201   469081             NaN             NaN             NaN
# 225204   469084             NaN             NaN             NaN
# 225606   470006             NaN             NaN             NaN
# 225682   470082             NaN             NaN             NaN
# 225722   470122             NaN             NaN             NaN
# 225723   470123             NaN             NaN             NaN
# 226205   471125             NaN             NaN             NaN
# 226643   472083             NaN             NaN             NaN
# 226687   472127             NaN             NaN             NaN
# 227046   473006             NaN             NaN             NaN
# 227606   474086             NaN             NaN             NaN
# 229321   477361             NaN             NaN             NaN
#
#         corr_station_3  corr_station_4  corr_station_5  corr_station_6  \
# 115904        0.743815        0.839400        0.702434        0.745927
# 115905        0.727606        0.848222        0.714748        0.732758
# 113987        0.781460        0.782592        0.612099        0.786879
# 116862        0.719154        0.803683        0.692231        0.717802
# 113504        0.765155        0.786952        0.618998        0.759675
# 113976        0.742158        0.810679        0.615475        0.747508
# 121661        0.762764        0.790183        0.677810        0.709376
# 114463        0.744536        0.780711        0.636593        0.734260
# 117336        0.727674        0.795090        0.648884        0.707231
# 113977        0.750432        0.802172        0.603616        0.751710
# 114936        0.734260        0.780743        0.627920        0.711826
# 112061        0.789589        0.761382        0.532918        0.770698
# 116866        0.719710        0.800483        0.710098        0.697112
# 115414        0.723134        0.792762        0.644977        0.708009
# 114457        0.746760        0.783111        0.611899        0.734557
# 115425        0.710162        0.838783        0.728122        0.751396
# 116865        0.707735        0.800819        0.737337        0.695987
# 115896        0.715020        0.796061        0.661068        0.707022
# 113978        0.743187        0.795091        0.598082        0.741280
# 114462        0.750107        0.783011        0.615202        0.752169
# 113974        0.749337        0.810905        0.628284        0.761711
# 113979        0.745990        0.805866        0.637431        0.738818
# 116376        0.693010        0.791277        0.647712        0.686689
# 112062        0.819908        0.756856        0.519626        0.803468
# 115421        0.750376        0.795045        0.652306        0.755920
# 111578        0.782531        0.795907        0.592093        0.799065
# 117814        0.662440        0.805739        0.701582        0.655044
# 114461        0.736980        0.790423        0.637280        0.744543
# 115417        0.719816        0.782823        0.648072        0.708736
# 115897        0.717403        0.773944        0.643133        0.695073
# ...                ...             ...             ...             ...
# 222848             NaN             NaN             NaN             NaN
# 223192             NaN             NaN             NaN             NaN
# 223273             NaN             NaN             NaN             NaN
# 223274             NaN             NaN             NaN             NaN
# 223275             NaN             NaN             NaN             NaN
# 223672             NaN             NaN             NaN             NaN
# 223677             NaN             NaN             NaN             NaN
# 223678             NaN             NaN             NaN             NaN
# 223686             NaN             NaN             NaN             NaN
# 223867             NaN             NaN             NaN             NaN
# 224152             NaN             NaN             NaN             NaN
# 224155             NaN             NaN             NaN             NaN
# 224156             NaN             NaN             NaN             NaN
# 224166             NaN             NaN             NaN             NaN
# 224534             NaN             NaN             NaN             NaN
# 224633             NaN             NaN             NaN             NaN
# 224646             NaN             NaN             NaN             NaN
# 225126             NaN             NaN             NaN             NaN
# 225201             NaN             NaN             NaN             NaN
# 225204             NaN             NaN             NaN             NaN
# 225606             NaN             NaN             NaN             NaN
# 225682             NaN             NaN             NaN             NaN
# 225722             NaN             NaN             NaN             NaN
# 225723             NaN             NaN             NaN             NaN
# 226205             NaN             NaN             NaN             NaN
# 226643             NaN             NaN             NaN             NaN
# 226687             NaN             NaN             NaN             NaN
# 227046             NaN             NaN             NaN             NaN
# 227606             NaN             NaN             NaN             NaN
# 229321             NaN             NaN             NaN             NaN
#
#         corr_station_7  corr_station_8       ...         corr_station_40  \
# 115904        0.671586        0.312172       ...                0.816810
# 115905        0.657291        0.279756       ...                0.825018
# 113987        0.665462        0.207083       ...                0.731076
# 116862        0.643570        0.288233       ...                0.815868
# 113504        0.680713        0.250499       ...                0.738939
# 113976        0.654015        0.279779       ...                0.759873
# 121661        0.680080        0.324942       ...                0.810100
# 114463        0.682226        0.297395       ...                0.765158
# 117336        0.643497        0.265099       ...                0.768853
# 113977        0.653835        0.273738       ...                0.753150
# 114936        0.643727        0.297368       ...                0.767419
# 112061        0.661650        0.246658       ...                0.657911
# 116866        0.612172        0.273632       ...                0.781831
# 115414        0.641283        0.294962       ...                0.778500
# 114457        0.659782        0.283930       ...                0.754264
# 115425        0.680670        0.314014       ...                0.829417
# 116865        0.640641        0.278270       ...                0.799259
# 115896        0.630677        0.285254       ...                0.777089
# 113978        0.662838        0.293161       ...                0.750280
# 114462        0.689857        0.264825       ...                0.748488
# 113974        0.681238        0.246833       ...                0.752003
# 113979        0.674843        0.271047       ...                0.763220
# 116376        0.602277        0.279765       ...                0.762115
# 112062        0.695103        0.218657       ...                0.646829
# 115421        0.697535        0.277700       ...                0.777586
# 111578        0.686620        0.246533       ...                0.686361
# 117814        0.591425        0.268095       ...                0.792146
# 114461        0.671906        0.267239       ...                0.761186
# 115417        0.632285        0.275722       ...                0.764540
# 115897        0.630424        0.272533       ...                0.760250
# ...                ...             ...       ...                     ...
# 222848             NaN             NaN       ...                     NaN
# 223192             NaN             NaN       ...                     NaN
# 223273             NaN             NaN       ...                     NaN
# 223274             NaN             NaN       ...                     NaN
# 223275             NaN             NaN       ...                     NaN
# 223672             NaN             NaN       ...                     NaN
# 223677             NaN             NaN       ...                     NaN
# 223678             NaN             NaN       ...                     NaN
# 223686             NaN             NaN       ...                     NaN
# 223867             NaN             NaN       ...                     NaN
# 224152             NaN             NaN       ...                     NaN
# 224155             NaN             NaN       ...                     NaN
# 224156             NaN             NaN       ...                     NaN
# 224166             NaN             NaN       ...                     NaN
# 224534             NaN             NaN       ...                     NaN
# 224633             NaN             NaN       ...                     NaN
# 224646             NaN             NaN       ...                     NaN
# 225126             NaN             NaN       ...                     NaN
# 225201             NaN             NaN       ...                     NaN
# 225204             NaN             NaN       ...                     NaN
# 225606             NaN             NaN       ...                     NaN
# 225682             NaN             NaN       ...                     NaN
# 225722             NaN             NaN       ...                     NaN
# 225723             NaN             NaN       ...                     NaN
# 226205             NaN             NaN       ...                     NaN
# 226643             NaN             NaN       ...                     NaN
# 226687             NaN             NaN       ...                     NaN
# 227046             NaN             NaN       ...                     NaN
# 227606             NaN             NaN       ...                     NaN
# 229321             NaN             NaN       ...                     NaN
#
#         corr_station_41  corr_station_42  corr_station_43  corr_station_44  \
# 115904         0.714358         0.703024         0.708546         0.664454
# 115905         0.714048         0.690225         0.720705         0.667988
# 113987         0.653738         0.642224         0.705022         0.649218
# 116862         0.704613         0.723659         0.730904         0.673126
# 113504         0.676045         0.650842         0.746825         0.680182
# 113976         0.661012         0.711049         0.755788         0.668573
# 121661         0.681373         0.653150         0.760262         0.749743
# 114463         0.700176         0.649436         0.765002         0.705473
# 117336         0.685151         0.700489         0.732379         0.702657
# 113977         0.669292         0.711590         0.754019         0.668122
# 114936         0.678259         0.716339         0.751889         0.687230
# 112061         0.626143         0.621622         0.733676         0.686450
# 116866         0.649960         0.668844         0.748140         0.672186
# 115414         0.684339         0.713933         0.768579         0.691533
# 114457         0.683025         0.724236         0.766321         0.692636
# 115425         0.719046         0.751168         0.771493         0.678012
# 116865         0.676177         0.683761         0.755034         0.683554
# 115896         0.693885         0.714147         0.747808         0.676373
# 113978         0.684345         0.705577         0.764636         0.670862
# 114462         0.682063         0.668484         0.783999         0.717817
# 113974         0.655562         0.700652         0.778241         0.708445
# 113979         0.700775         0.665607         0.788547         0.692046
# 116376         0.671591         0.711746         0.720176         0.648685
# 112062         0.611314         0.625392         0.775760         0.730177
# 115421         0.686952         0.710757         0.789899         0.730220
# 111578         0.646261         0.669282         0.744978         0.670220
# 117814         0.701482         0.673762         0.696825         0.651722
# 114461         0.691095         0.697181         0.783468         0.703996
# 115417         0.679749         0.715748         0.755719         0.679404
# 115897         0.682559         0.680089         0.738348         0.685204
# ...                 ...              ...              ...              ...
# 222848              NaN              NaN              NaN              NaN
# 223192              NaN              NaN              NaN              NaN
# 223273              NaN              NaN              NaN              NaN
# 223274              NaN              NaN              NaN              NaN
# 223275              NaN              NaN              NaN              NaN
# 223672              NaN              NaN              NaN              NaN
# 223677              NaN              NaN              NaN              NaN
# 223678              NaN              NaN              NaN              NaN
# 223686              NaN              NaN              NaN              NaN
# 223867              NaN              NaN              NaN              NaN
# 224152              NaN              NaN              NaN              NaN
# 224155              NaN              NaN              NaN              NaN
# 224156              NaN              NaN              NaN              NaN
# 224166              NaN              NaN              NaN              NaN
# 224534              NaN              NaN              NaN              NaN
# 224633              NaN              NaN              NaN              NaN
# 224646              NaN              NaN              NaN              NaN
# 225126              NaN              NaN              NaN              NaN
# 225201              NaN              NaN              NaN              NaN
# 225204              NaN              NaN              NaN              NaN
# 225606              NaN              NaN              NaN              NaN
# 225682              NaN              NaN              NaN              NaN
# 225722              NaN              NaN              NaN              NaN
# 225723              NaN              NaN              NaN              NaN
# 226205              NaN              NaN              NaN              NaN
# 226643              NaN              NaN              NaN              NaN
# 226687              NaN              NaN              NaN              NaN
# 227046              NaN              NaN              NaN              NaN
# 227606              NaN              NaN              NaN              NaN
# 229321              NaN              NaN              NaN              NaN
#
#         corr_station_45  corr_station_46  corr_station_47  corr_station_48  \
# 115904         0.493947         0.390061         0.836444         0.704287
# 115905         0.513642         0.372627         0.841287         0.690155
# 113987         0.484623         0.260560         0.748928         0.636124
# 116862         0.469931         0.421651         0.839041         0.637604
# 113504         0.454156         0.328116         0.773486         0.632247
# 113976         0.475772         0.406832         0.784292         0.628626
# 121661         0.435853         0.455026         0.811421         0.707224
# 114463         0.440733         0.386193         0.793935         0.632321
# 117336         0.455658         0.433159         0.789950         0.636288
# 113977         0.468652         0.397046         0.782996         0.626315
# 114936         0.483297         0.448572         0.796439         0.590996
# 112061         0.411277         0.323019         0.699214         0.614718
# 116866         0.514138         0.397342         0.811144         0.640723
# 115414         0.494467         0.445372         0.799618         0.601353
# 114457         0.463814         0.415337         0.786843         0.610815
# 115425         0.497494         0.413146         0.832919         0.708239
# 116865         0.508939         0.404068         0.834499         0.666432
# 115896         0.499515         0.456502         0.814804         0.611111
# 113978         0.464176         0.409368         0.786004         0.613543
# 114462         0.423532         0.367882         0.776427         0.648311
# 113974         0.463758         0.368750         0.769727         0.650265
# 113979         0.444817         0.388305         0.801330         0.642078
# 116376         0.479068         0.461628         0.793413         0.594894
# 112062         0.360172         0.272122         0.683097         0.640220
# 115421         0.432918         0.386518         0.792182         0.674878
# 111578         0.445208         0.310496         0.734153         0.655888
# 117814         0.509990         0.473222         0.821999         0.607683
# 114461         0.434204         0.382319         0.785031         0.635207
# 115417         0.472704         0.425944         0.803205         0.610871
# 115897         0.468092         0.440842         0.807902         0.600703
# ...                 ...              ...              ...              ...
# 222848              NaN              NaN              NaN              NaN
# 223192              NaN              NaN              NaN              NaN
# 223273              NaN              NaN              NaN              NaN
# 223274              NaN              NaN              NaN              NaN
# 223275              NaN              NaN              NaN              NaN
# 223672              NaN              NaN              NaN              NaN
# 223677              NaN              NaN              NaN              NaN
# 223678              NaN              NaN              NaN              NaN
# 223686              NaN              NaN              NaN              NaN
# 223867              NaN              NaN              NaN              NaN
# 224152              NaN              NaN              NaN              NaN
# 224155              NaN              NaN              NaN              NaN
# 224156              NaN              NaN              NaN              NaN
# 224166              NaN              NaN              NaN              NaN
# 224534              NaN              NaN              NaN              NaN
# 224633              NaN              NaN              NaN              NaN
# 224646              NaN              NaN              NaN              NaN
# 225126              NaN              NaN              NaN              NaN
# 225201              NaN              NaN              NaN              NaN
# 225204              NaN              NaN              NaN              NaN
# 225606              NaN              NaN              NaN              NaN
# 225682              NaN              NaN              NaN              NaN
# 225722              NaN              NaN              NaN              NaN
# 225723              NaN              NaN              NaN              NaN
# 226205              NaN              NaN              NaN              NaN
# 226643              NaN              NaN              NaN              NaN
# 226687              NaN              NaN              NaN              NaN
# 227046              NaN              NaN              NaN              NaN
# 227606              NaN              NaN              NaN              NaN
# 229321              NaN              NaN              NaN              NaN
#
#         corr_station_49
# 115904         0.457008
# 115905         0.412839
# 113987         0.280807
# 116862         0.432010
# 113504         0.279572
# 113976         0.310238
# 121661         0.534043
# 114463         0.349848
# 117336         0.375132
# 113977         0.303533
# 114936         0.327829
# 112061         0.255744
# 116866         0.407207
# 115414         0.344230
# 114457         0.318226
# 115425         0.443108
# 116865         0.449514
# 115896         0.354615
# 113978         0.296685
# 114462         0.332626
# 113974         0.305656
# 113979         0.333903
# 116376         0.344954
# 112062         0.258789
# 115421         0.387954
# 111578         0.276740
# 117814         0.385311
# 114461         0.329034
# 115417         0.348975
# 115897         0.344119
# ...                 ...
# 222848              NaN
# 223192              NaN
# 223273              NaN
# 223274              NaN
# 223275              NaN
# 223672              NaN
# 223677              NaN
# 223678              NaN
# 223686              NaN
# 223867              NaN
# 224152              NaN
# 224155              NaN
# 224156              NaN
# 224166              NaN
# 224534              NaN
# 224633              NaN
# 224646              NaN
# 225126              NaN
# 225201              NaN
# 225204              NaN
# 225606              NaN
# 225682              NaN
# 225722              NaN
# 225723              NaN
# 226205              NaN
# 226643              NaN
# 226687              NaN
# 227046              NaN
# 227606              NaN
# 229321              NaN
#
# [230400 rows x 51 columns]

# %%
len(np.where(pd.isnull(df_corr_result))[0])
# Out:
# 24600

# %%
latlong = df_corr_result.values[:,0]

# %%
df_corr_result_array = df_corr_result.values[:,1:]
df_corr_result_array.shape
# Out:
# (230400, 50)

# %%
def to_lat(latlong):
    return int(latlong // 1000)

def to_long(latlong):
    return int(latlong % 1000)

# %%
dict_result = {}
for station in range(df_corr_result_array.shape[1]):
    values = df_corr_result_array[:, station]
    index = np.nanargmax(values)
    dict_result[str(station)] = {
    'lat' : to_lat(latlong[index]),
    'long': to_long(latlong[index])
    }

# %%
import json
with open('station_location.json', 'w') as outfile:
    json.dump(dict_result, outfile)

# %%
dict_result
# Out:
# {'0': {'lat': 241, 'long': 224},
#  '1': {'lat': 241, 'long': 102},
#  '10': {'lat': 256, 'long': 144},
#  '11': {'lat': 242, 'long': 154},
#  '12': {'lat': 188, 'long': 156},
#  '13': {'lat': 253, 'long': 201},
#  '14': {'lat': 245, 'long': 170},
#  '15': {'lat': 251, 'long': 157},
#  '16': {'lat': 253, 'long': 201},
#  '17': {'lat': 232, 'long': 248},
#  '18': {'lat': 273, 'long': 181},
#  '19': {'lat': 230, 'long': 179},
#  '2': {'lat': 253, 'long': 221},
#  '20': {'lat': 214, 'long': 116},
#  '21': {'lat': 230, 'long': 179},
#  '22': {'lat': 202, 'long': 117},
#  '23': {'lat': 236, 'long': 247},
#  '24': {'lat': 229, 'long': 160},
#  '25': {'lat': 242, 'long': 152},
#  '26': {'lat': 217, 'long': 118},
#  '27': {'lat': 249, 'long': 164},
#  '28': {'lat': 274, 'long': 122},
#  '29': {'lat': 241, 'long': 224},
#  '3': {'lat': 197, 'long': 166},
#  '30': {'lat': 248, 'long': 195},
#  '31': {'lat': 249, 'long': 139},
#  '32': {'lat': 268, 'long': 173},
#  '33': {'lat': 255, 'long': 143},
#  '34': {'lat': 239, 'long': 205},
#  '35': {'lat': 191, 'long': 154},
#  '36': {'lat': 267, 'long': 190},
#  '37': {'lat': 215, 'long': 115},
#  '38': {'lat': 237, 'long': 248},
#  '39': {'lat': 226, 'long': 139},
#  '4': {'lat': 239, 'long': 205},
#  '40': {'lat': 193, 'long': 156},
#  '41': {'lat': 231, 'long': 180},
#  '42': {'lat': 213, 'long': 122},
#  '43': {'lat': 210, 'long': 184},
#  '44': {'lat': 214, 'long': 178},
#  '45': {'lat': 265, 'long': 158},
#  '46': {'lat': 257, 'long': 106},
#  '47': {'lat': 240, 'long': 194},
#  '48': {'lat': 174, 'long': 204},
#  '49': {'lat': 297, 'long': 200},
#  '5': {'lat': 249, 'long': 164},
#  '6': {'lat': 237, 'long': 247},
#  '7': {'lat': 232, 'long': 248},
#  '8': {'lat': 241, 'long': 102},
#  '9': {'lat': 260, 'long': 190}}
